# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("sales_sample.csv", parse_dates=["Date"])

# %%
print(df.shape)
df.head()
# Out:
# (7310, 9)
#         Date Store StoreType   Sales  Customers  Promo  Holiday  DayOfWeek  \
# 0 2023-09-15   S03         A  153.89          8      0        0          4
# 1 2023-06-06   S02         A  253.16         10      0        0          1
# 2 2023-10-08   S06         A  121.96          5      0        0          6
# 3 2024-09-01   S09         C  125.07          6      0        0          6
# 4 2023-10-23   S08         A   99.00          5      0        0          0
#
#    CompetitionDistance
# 0                785.8
# 1                790.2
# 2               1088.5
# 3                979.2
# 4               1024.6

# %%
df.isna().sum()
# Out:
# Date                   0
# Store                  0
# StoreType              0
# Sales                  0
# Customers              0
# Promo                  0
# Holiday                0
# DayOfWeek              0
# CompetitionDistance    0
# dtype: int64

# %%
df['Store'].nunique()
# Out:
# 10

# %%
df.groupby('Date')['Sales'].sum().plot()
# Out:
# <Axes: xlabel='Date'>
